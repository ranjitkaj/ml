# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np

# %%
import sklearn.linear_model as lm

# %%
df = pd.read_csv('ml.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   plot    7 non-null      int64
#  1   rate    7 non-null      int64
# dtypes: int64(2)
# memory usage: 244.0 bytes

# %%
df.describe()
# Out:
#              plot           rate
# count    7.000000       7.000000
# mean   250.000000  125000.000000
# std    108.012345   54006.172487
# min    100.000000   50000.000000
# 25%    175.000000   87500.000000
# 50%    250.000000  125000.000000
# 75%    325.000000  162500.000000
# max    400.000000  200000.000000

# %%
plt.scatter(df['plot'], df['rate'])
plt.xlabel('plot size in squre meter')
plt.ylabel('plot cost in inr')
plt.show()

# %%
df.plot()
# Out:
# <Axes: >

# %%
a = lm.LinearRegression()
a.fit(df[['plot']],df['rate'])
# Out:
# LinearRegression()

# %%
a
# Out:
# LinearRegression()

# %%
df1 = df.drop('rate', axis=1)
df1
# Out:
#    plot
# 0   100
# 1   150
# 2   200
# 3   250
# 4   300
# 5   350
# 6   400

# %%
df2 = df.drop('plot', axis=1)
df2
# Out:
#      rate
# 0   50000
# 1   75000
# 2  100000
# 3  125000
# 4  150000
# 5  175000
# 6  200000

# %%
b = linear_model.LinearRegression()
b.fit(df1,df2)
# Out:
# LinearRegression()

# %%
b.predict([[10000]])
# Out:
# C:\Users\ranji\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[5000000.]])

# %%
a.coef_
# Out:
# array([500.])

# %%
a.intercept_
# Out:
# -4.3655745685100555e-11

# %%
c = pd.read_csv('ab.csv')
c
# Out:
#    plot
# 0   341
# 1   420
# 2   280
# 3   123
# 4   600
# 5   478
# 6  1200

# %%
d = b.predict(c)

# %%
c['estimations'] = d

# %%
c.to_csv('a.csv', index=False)

# %%
plt.scatter(df['plot'], df['rate'])
plt.plot(df['plot'])

# %%
df_f = pd.read_csv('a.csv')

# %%
plt.scatter(df_f['plot'], df_f['estimations'])
plt.grid()
plt.plot(df_f['plot'], df_f['estimations'])
